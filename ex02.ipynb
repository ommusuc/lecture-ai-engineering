# %% [markdown]
# # Assignment for #05, 06, and 07

# %% [markdown]
# Downloading auxiliary classes:

# %%
# %%bash
# wget --no-check-certificate -O "chap3lib.7z" "https://docs.google.com/uc?export=download&id=1SuDvAXGqR17finK7rO9xsqQh2Hey1VVQ"
# 7z x chap3lib.7z
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 3919 bytes (4 KiB)
#
# Extracting archive: chap3lib.7z
# --
# Path = chap3lib.7z
# Type = 7z
# Physical Size = 3919
# Headers Size = 130
# Method = LZMA2:24k
# Solid = -
# Blocks = 1
#
#
# Would you like to replace the existing file:
#   Path:     ./chap3lib.py
#   Size:     19281 bytes (19 KiB)
#   Modified: 2025-05-08 18:20:27
# with the file from archive:
#   Path:     chap3lib.py
#   Size:     19281 bytes (19 KiB)
#   Modified: 2025-05-08 18:20:27
# ? (Y)es / (N)o / (A)lways / (S)kip all / A(u)to rename all / (Q)uit?
# --2025-05-12 00:29:58--  https://docs.google.com/uc?export=download&id=1SuDvAXGqR17finK7rO9xsqQh2Hey1VVQ
# Resolving docs.google.com (docs.google.com)... 172.253.62.101, 172.253.62.102, 172.253.62.100, ...
# Connecting to docs.google.com (docs.google.com)|172.253.62.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1SuDvAXGqR17finK7rO9xsqQh2Hey1VVQ&export=download [following]
# --2025-05-12 00:29:58--  https://drive.usercontent.google.com/download?id=1SuDvAXGqR17finK7rO9xsqQh2Hey1VVQ&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.253.115.132, 2607:f8b0:4004:c06::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.253.115.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3919 (3.8K) [application/octet-stream]
# Saving to: ‘chap3lib.7z’
#
#      0K ...                                                   100% 35.9M=0s
#
# 2025-05-12 00:30:00 (35.9 MB/s) - ‘chap3lib.7z’ saved [3919/3919]
#
# terminate called after throwing an instance of 'char const*'
# bash: line 2:  6621 Aborted                 (core dumped) 7z x chap3lib.7z
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-10-04ab24b65e2d> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'wget --no-check-certificate -O "chap3lib.7z" "https://docs.google.com/uc?export=download&id=1SuDvAXGqR17finK7rO9xsqQh2Hey1VVQ"\n7z x chap3lib.7z\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     356     if line and not cell:
#     357       cell = ' '
# --> 358     return super().run_cell_magic(magic_name, line, cell)
#     359
#     360
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'wget --no-check-certificate -O "chap3lib.7z" "https://docs.google.com/uc?export=download&id=1SuDvAXGqR17finK7rO9xsqQh2Hey1VVQ"\n7z x chap3lib.7z\n'' returned non-zero exit status 134.

# %% [markdown]
# Importing auxiliary classes:

# %%
from chap3lib import *

# %% [markdown]
# ## A1.

# %% [markdown]
# **Objective:**
#
# The goal of this assignment is to define the `Exp2Alg` interface, which defines the operations for constructing expressions in the `Exp2` language. You will need to fill in the methods that currently raise `NotImplementedError()`.
#
# **Background:**
#
# The `Exp2` language is a small functional kernel whose syntax includes constants (integers and booleans), variables, unary and binary operations, conditional expressions, local bindings, function definitions (including recursive ones), and function applications. Each of these syntactic constructs corresponds to a method in the `Exp2Alg` interface.
#
# Object Algebras provide a way to define language syntax and semantics separately. The `Exp2Alg` acts as an interface (algebra) that defines operations for each language construct of `Exp2`.

# %%
class Exp2Alg:
    def cint(self, v):
      raise NotImplementedError()
    def cbool(self, v):
      raise NotImplementedError()
    def var(self, x):
      raise NotImplementedError()
    def _not(self, e):
      raise NotImplementedError()
    def plus(self, e1, e2):
      raise NotImplementedError()
    def minus(self, e1, e2):
      raise NotImplementedError()
    def div(self, e1, e2):
      raise NotImplementedError()
    def mult(self, e1, e2):
      raise NotImplementedError()
    def _and(self, e1, e2):
      raise NotImplementedError()
    def _or(self, e1, e2):
      raise NotImplementedError()
    def eq(self, e1, e2):
      raise NotImplementedError()
    def le(self, e1, e2):
      raise NotImplementedError()
    def cond(self, e1, e2, e3):
      raise NotImplementedError()
    def let(self, x, e1, e2):
      raise NotImplementedError()
    def fun(self, x, e):
      raise NotImplementedError()
    #再帰処理
    def rec(self, f, x, e):
      raise NotImplementedError()
    #関数の適用を定義
    def app(self, e1, e2):
      raise NotImplementedError()

# %% [markdown]
# ## A2.

# %% [markdown]
# **Objective:**
#
# The goal of this assignment is to practice representing `Exp2` language constructs using the Object Algebra pattern. You will define a Python function that takes an instance of an `Exp2Alg` implementation and uses its methods to construct the `Exp2` expression `let x = 10 in (x + 5)`.
#
# **Background:**
#
# As discussed in the lecture, `Exp2` expressions can be programmatically constructed in Python by calling methods on an object that implements the `Exp2Alg` interface. Each method on this `alg` object corresponds to a specific syntactic construct in the `Exp2` language.
#
# For example:
# * A constant integer like `10` would be created using `alg.cint(10)`.
# * A variable like `x` would be created using `alg.var("x")`.
# * An addition expression like `e1 + e2` would be created using `alg.plus(e1, e2)`.
# * A let-binding expression `let x = e1 in e2` would be created using `alg.let("x", e1, e2)`.
#
# **Task:**
#
# Define a Python function, let's call it `let_example`, that takes a single argument:
# * `alg`: An instance of a class that implements the `Exp2Alg` interface.
#
# This function should use the methods of the `alg` object to construct and return the representation of the following `Exp2` expression:
#
# `let x = 10 in (x + 5)`

# %%
def let_example(alg):
  return alg.let('x',alg.cint(10),alg.plus(alg.var('x'),alg.cint(5)))

# %% [markdown]
# ## A3.

# %% [markdown]
# **Objective:**
#
# The primary goal of this assignment is to implement a call-by-value evaluation function for the `Exp2` language. You will achieve this by creating a Python class named `Exp2Eval` that implements the `Exp2Alg` interface. The methods in your `Exp2Eval` class will not directly return values, but rather "computations" – functions that, when given an environment, will produce the evaluated result (a value or an error).
#
# **Background:**
#
# The call-by-value evaluation rules for `Exp2` expressions are specified formally as $[[e]]_{Env}$ on the lecture slides. A strategy for implementing such an evaluator using object algebras, where algebra methods return computations (functions), is also discussed on the slides. This is the strategy you must follow.
#
# You will use parts of the provided `chap3lib.py` for this assignment, including:
# * Value classes: `Value`, `VInt2`, `VBool2`, `Clos2`, and `ClosRec2`.
# * Error classes: `Err2`, `E_Typ2` (type error), `E_Exec2` (execution error, e.g., division by zero), `E_Undef2` (unbound variable).
# * Environment lookup function: `lookup_env(env, name)`.

# %%
# 要はいったん環境を挟んでから返す
class Eval2Alg(Exp2Alg):
  def cint(self,v):
    def _eval(env):
      return VInt2(v)
    return _eval
  def cbool(self,v):
    def _eval(env):
      return VBool2(v)
    return _eval
  def var(self,x):
    def _eval(env):
      # 環境からxに束縛されている値を参照
      val = lookup_env(env,x)
      if val is None:
        raise E_Undef2()
      return val
    return _eval
  def _not(self,e):
    def _eval(env):
      # eの評価結果を返す(ここではVBool型)
      v = e(env)
      if not isinstance(v,VBool2):
        raise E_Typ2()
      # v自体はインスタンスなのでv.vで本物の値を参照
      return VBool2(not v.v)
    return _eval
  def plus(self,e1,e2):
    def _eval(env):
      v1 = e1(env)
      v2 = e2(env)
      if not isinstance(v1,VInt2) or not isinstance(v2,VInt2):
        raise E_Typ2()
      return VInt2(v1.v + v2.v)
    return _eval

  def minus(self,e1,e2):
    def _eval(env):
      v1 = e1(env)
      v2 = e2(env)
      if not isinstance(v1,VInt2) or not isinstance(v2,VInt2):
        raise E_Typ2()
      return VInt2(v1.v - v2.v)
    return _eval

  def div(self,e1,e2):
    def _eval(env):
      v1 = e1(env)
      v2 = e2(env)
      if not isinstance(v1,VInt2) or not isinstance(v2,VInt2):
        raise E_Typ2()
      if v2.v == 0:
        raise E_Exec2()
      # 集合は整数とまり実数は許さないので切り捨て
      return VInt2(v1.v // v2.v)
    return _eval

  def mult(self,e1,e2):
    def _eval(env):
      v1 = e1(env)
      v2 = e2(env)
      if not isinstance(v1,VInt2) or not isinstance(v2,VInt2):
        raise E_Typ2()
      return VInt2(v1.v * v2.v)
    return _eval

  # IntとBool両方を確認
  def eq(self,e1,e2):
    def _eval(env):
      v1 = e1(env)
      v2 = e2(env)
      if (isinstance(v1,VInt2) and isinstance(v2,VInt2)) or (isinstance(v1,VBool2) and isinstance(v2,VBool2)):
        return VBool2(v1.v == v2.v)
      return E_Typ2()
    return _eval

  # 小なりかを判断
  def le(self,e1,e2):
    def _eval(env):
      v1 = e1(env)
      v2 = e2(env)
      if not isinstance(v1,VInt2) or not isinstance(v2,VInt2):
        raise E_Typ2()
      return VBool2(v1.v <= v2.v)
    return _eval
  #　なんでv2,v3そのまま返すんですか？
  def cond(self,e1,e2,e3):
    def _eval(env):
      v1 = e1(env)

      if not isinstance(v1,VBool2):
        raise E_Typ2()
      if v1.v:
        v2 = e2(env)
        return v2
      else:
        v3 = e3(env)
        return v3
    return _eval

  def let(self,x,e1,e2):
    def _eval(env):
      v1 = e1(env)
      new_env = [(x,v1)] + env
      return e2(new_env)
    return _eval

  def fun(self,x,e):
    def _eval(env):
      # 静的スコープを用いて関数実行
      return Clos2(x,e,env)
    return _eval

  def rec(self,f,x,e):
    def _eval(env):
      return ClosRec2(f,x,e,env)
    return _eval

  def app(self,e1,e2):
    # e1が関数 or 再帰かどうかで処理が変わる
    def _eval(env):
      v_fun = e1(env)
      v_arg = e2(env)

      if isinstance(v_fun,Clos2):
        app_env = [(v_fun.x,v_arg)] + v_fun.env
        return v_fun.e(app_env)
      elif isinstance(v_fun,ClosRec2):
        app_env = [(v_fun.f,v_fun),(v_fun.x,v_arg)] + v_fun.env
        return v_fun.e(app_env)
      else:
        raise E_Typ2()
    return _eval

# %% [markdown]
# ## A4.

# %% [markdown]
# **Objective:**
#
# The goal of this assignment is to implement a derivation tree generator for the `Exp2` language under Call-by-Value operational semantics. You will create a Python class `Exp2EvalTreeGenerator` that implements the `Exp2Alg` interface. Instead of directly evaluating to a final value, each method in this algebra will contribute to constructing a representation of the expression's Abstract Syntax Tree (AST) and a "computation" that, when executed with an environment, produces an `EvalStepNode`. This `EvalStepNode` (or one of its specific subclasses `F1` through `F20` from `chap3lib.py`) represents the root of the derivation (sub)tree for that part of the expression.
#
# **Background:**
#
# * The `Exp2` language syntax and its `Exp2Alg` interface are defined in the lecture slides.
# * The Call-by-Value operational semantics rules (F1-F20) are described in the lecture slides.
# * The provided `chap3lib.py` file contains:
#     * AST node classes (`ANode`, `AConst`, `AVar`, `AUnOpExp`, `ABinOpExp`, `ACond`, `ALet`, `AFun`, `ARec`, `AApp`, and specific operator classes like `APlus`, `ANotOp`).
#     * Value classes (`Val2`, `VInt2`, `VBool2`) and Error classes (`Err2`, `E_Typ2`, `E_Exec2`, `E_Undef2`).
#     * Environment utilities (`lookup_env`).
#     * Closure classes `Clos2` and `ClosRec2` which store an `ANode` for the body and a callable to get an `EvalStepNode`. These are suitable for this assignment.
#     * `EvalStepNode` class and its subclasses `F1` through `F20`, which you **must use** to represent each step in the derivation tree. Each `Fk` class constructor typically requires the current environment, the AST node of the expression being evaluated (`expr_ast`), the resulting value/error, and any premise `EvalStepNode`s.

# %%
class Exp2EvalTreeGenerator(Exp2Alg):
  def cint(self,v):
    def _eval(env):
      expr_ast = AConst(VInt2(v))
      return F1(env,expr_ast,VInt2(v))
    return _eval

  def cbool(self,v):
    def _eval(env):
      expr_ast = AConst(VBool2(v))
      return F1(env,expr_ast,VBool2(v))
    return _eval

  def var(self,x):
    def _eval(env):
      expr_ast = AVar(x)
      # 環境からxに束縛されている値を参照
      val = lookup_env(env,x)
      if val is None:
        eval_step = F12(env,expr_ast,E_Undef2(),var_name = x)
      else:
        eval_step = F11(env,expr_ast,val,var_name=x)
      return eval_step
    return _eval


  def _not(self,e):
    def _eval(env):
      # eは単項演算子
      premise_e= e(env)
      expr_ast = AUnOpExp(ANotOp(),e)

      if isinstance(premise_e,VBool2):
        result_value = VBool2(not premise_e.result_value)
        eval_step = F2(env,expr_ast,result_value,premise_e,ANotOp())
      else:
        eval_step = F3(env,expr_ast,E_Typ2(),premise_e,ANotOp())
      return eval_step
    return _eval

  def plus(self, e1, e2):
    def _eval(env):
        premise_e1 = e1(env)  # 第一オペランドの評価
        expr_ast = ABinOpExp(APlus(), e1, e2)  # AST ノードを作成

        if isinstance(premise_e1.result_value, Err2):  # e1 の評価がエラーの場合
            eval_step = F5(env, expr_ast, premise_e1.result_value, premise_e1, APlus())  # F5: e1 の評価がエラー
            return eval_step

        premise_e2 = e2(env)  # 第二オペランドの評価

        if isinstance(premise_e2.result_value, Err2):  # e2 の評価がエラーの場合
            eval_step = F6(env, expr_ast, premise_e2.result_value, premise_e1, premise_e2, APlus())  # F6: e2 の評価がエラー
            return eval_step

        if isinstance(premise_e1.result_value, VInt2) and isinstance(premise_e2.result_value, VInt2):  # 両方とも整数なら加算
            result_value = VInt2(premise_e1.result_value.v + premise_e2.result_value.v)
            eval_step = F4(env, expr_ast, result_value, premise_e1, premise_e2, APlus())  # F4: `e1 + e2` の評価
        else:
            eval_step = F6(env, expr_ast, E_Typ2(), premise_e1, premise_e2, APlus())  # F6: 型エラー

        return eval_step
    return _eval



  def minus(self,e1,e2):
    def _eval(env):
        premise_e1 = e1(env)  # 第一オペランドの評価
        expr_ast = ABinOpExp(AMinus(), e1, e2)  # AST ノードを作成

        if isinstance(premise_e1.result_value, Err2):  # e1 の評価がエラーの場合
            eval_step = F5(env, expr_ast, premise_e1.result_value, premise_e1, AMinus())  # F5: e1 の評価がエラー
            return eval_step

        premise_e2 = e2(env)  # 第二オペランドの評価

        if isinstance(premise_e2.result_value, Err2):  # e2 の評価がエラーの場合
            eval_step = F6(env, expr_ast, premise_e2.result_value, premise_e1, premise_e2, AMinus())  # F6: e2 の評価がエラー
            return eval_step

        if isinstance(premise_e1.result_value, VInt2) and isinstance(premise_e2.result_value, VInt2):  # 両方とも整数なら加算
            result_value = VInt2(premise_e1.result_value.v - premise_e2.result_value.v)
            eval_step = F4(env, expr_ast, result_value, premise_e1, premise_e2, AMinus())  # F4: `e1 + e2` の評価
        else:
            eval_step = F6(env, expr_ast, E_Typ2(), premise_e1, premise_e2, AMinus())  # F6: 型エラー

        return eval_step
    return _eval


  def div(self,e1,e2):
    def _eval(env):

      premise_e1 = e1(env)  # 第一オペランドの評価
      expr_ast = ABinOpExp(ADiv(), e1, e2)  # AST ノードを作成

      if isinstance(premise_e1.result_value, Err2):  # e1 の評価がエラーの場合
          eval_step = F5(env, expr_ast, premise_e1.result_value, premise_e1, ADiv())  # F5: e1 の評価がエラー
          return eval_step

      premise_e2 = e2(env)  # 第二オペランドの評価

      if isinstance(premise_e2.result_value, Err2):  # e2 の評価がエラーの場合
          eval_step = F6(env, expr_ast, premise_e2.result_value, premise_e1, premise_e2, ADiv())  # F6: e2 の評価がエラー
          return eval_step

      if isinstance(premise_e1.result_value, VInt2) and isinstance(premise_e2.result_value, VInt2):  # 両方とも整数なら除算
          if premise_e2.result_value.v == 0:  # ゼロ除算のチェック
              eval_step = F6(env, expr_ast, E_Exec2(), premise_e1, premise_e2, ADiv())  # F6b: ゼロ除算エラー
          else:
              result_value = VInt2(premise_e1.result_value.v // premise_e2.result_value.v) # 実数は許さないので除算
              eval_step = F4(env, expr_ast, result_value, premise_e1, premise_e2, ADiv())  # F4: 除算演算の評価
      else:
          eval_step = F6(env, expr_ast, E_Typ2(), premise_e1, premise_e2, ADiv())  # F6: 型エラー
      return eval_step
    return _eval


  def mult(self,e1,e2):
    def _eval(env):
        premise_e1 = e1(env)  # 第一オペランドの評価
        expr_ast = ABinOpExp(AMult(), e1, e2)  # AST ノードを作成

        if isinstance(premise_e1.result_value, Err2):  # e1 の評価がエラーの場合
            eval_step = F5(env, expr_ast, premise_e1.result_value, premise_e1, AMult())  # F5: e1 の評価がエラー
            return eval_step

        premise_e2 = e2(env)  # 第二オペランドの評価

        if isinstance(premise_e2.result_value, Err2):  # e2 の評価がエラーの場合
            eval_step = F6(env, expr_ast, premise_e2.result_value, premise_e1, premise_e2, AMult())  # F6: e2 の評価がエラー
            return eval_step

        if isinstance(premise_e1.result_value, VInt2) and isinstance(premise_e2.result_value, VInt2):  # 両方とも整数なら加算
            result_value = VInt2(premise_e1.result_value.v * premise_e2.result_value.v)
            eval_step = F4(env, expr_ast, result_value, premise_e1, premise_e2, AMult())  # F4: `e1 + e2` の評価
        else:
            eval_step = F6(env, expr_ast, E_Typ2(), premise_e1, premise_e2, AMult())  # F6: 型エラー

        return eval_step
    return _eval

  # IntとBool両方を確認
  def eq(self,e1,e2):
    def _eval(env):
      premise_e1 = e1(env)  # 第一オペランドの評価
      expr_ast = ABinOpExp(AEq(), e1, e2)  # AST ノードを作成

      if isinstance(premise_e1.result_value, Err2):  # e1 の評価がエラーの場合
          eval_step = F5(env, expr_ast, premise_e1.result_value, premise_e1, AEq())  # F5: e1 の評価がエラー
          return eval_step

      premise_e2 = e2(env)  # 第二オペランドの評価

      if isinstance(premise_e2.result_value, Err2):  # e2 の評価がエラーの場合
          eval_step = F6(env, expr_ast, premise_e2.result_value, premise_e1, premise_e2, AEq())  # F6: e2 の評価がエラー
          return eval_step

      if (isinstance(premise_e1.result_value, VInt2) and isinstance(premise_e2.result_value, VInt2)) or (isinstance(premise_e1, VBool2) and isinstance(premise_e2, VBool2)):

          result_value = VBool2(premise_e1.result_value.v == premise_e2.result_value.v) # 実数は許さないので除算
          eval_step = F4(env, expr_ast, result_value, premise_e1, premise_e2, AEq())  # F4: 除算演算の評価
      else:
          eval_step = F6(env, expr_ast, E_Typ2(), premise_e1, premise_e2, AEq())  # F6: 型エラー
      return eval_step
    return _eval

  # 小なりかを判断
  def le(self,e1,e2):
    def _eval(env):
      premise_e1 = e1(env)  # 第一オペランドの評価
      expr_ast = ABinOpExp(ALe(), e1, e2)  # AST ノードを作成

      if isinstance(premise_e1.result_value, Err2):  # e1 の評価がエラーの場合
          eval_step = F5(env, expr_ast, premise_e1.result_value, premise_e1, ALe())  # F5: e1 の評価がエラー
          return eval_step

      premise_e2 = e2(env)  # 第二オペランドの評価

      if isinstance(premise_e2.result_value, Err2):  # e2 の評価がエラーの場合
          eval_step = F6(env, expr_ast, premise_e2.result_value, premise_e1, premise_e2, ALe())  # F6: e2 の評価がエラー
          return eval_step

      if (isinstance(premise_e1.result_value, VInt2) and isinstance(premise_e2.result_value, VInt2)):  # 両方とも整数なら除算
          result_value = VBool2(premise_e1.result_value.v <= premise_e2.result_value.v) # 実数は許さないので除算
          eval_step = F4(env, expr_ast, result_value, premise_e1, premise_e2, ALe())  # F4: 除算演算の評価
      else:
          eval_step = F6(env, expr_ast, E_Typ2(), premise_e1, premise_e2, ALe())  # F6: 型エラー
      return eval_step
    return _eval

  #　なんでv2,v3そのまま返すんですか？
  def cond(self,e1,e2,e3):
    def _eval(env):
      premise_e1 = e1(env)  # 第一オペランドの評価
      expr_ast = ACond(e1,e2,e3)  # AST ノードを作成

      if isinstance(premise_e1.result_value, Err2):  # e1 の評価がエラーの場合
          eval_step = F10(env, expr_ast, premise_e1.result_value, premise_e1, premise_e2)  # F5: e1 の評価がエラー
          return eval_step
      if isinstance(premise_e1.result_value,VBool2):
        if premise_e1.result_value.v:
          premise_e2 = e2(env)  # 第二オペランドの評価
          eval_step = F7(env,expr_ast,premise_e2.result_value,premise_e1,premise_e2)
        else:
          premise_e3 = e3(env)  # 第三オペランドの評価
          eval_step = F8(env,expr_ast,premise_e3.result_value,premise_e1,premise_e3)
      else:
        eval_step = F9(env,expr_ast,E_Typ2(),premise_e1)
      return eval_step
    return _eval

  def let(self, x, e1, e2):
    def _eval(env):
      premise_e1 = e1(env)  # `e1` の評価
      expr_ast = ALet(x, e1, e2)  # AST ノードの作成

      if isinstance(premise_e1.result_value, Err2):  # `e1` の評価がエラーの場合
        eval_step = F14(env, expr_ast, premise_e1.result_value, premise_e1, x)  # F14: `e1` の評価がエラー
        return eval_step

      # `e1` の評価結果を環境へ追加
      new_env = [(x, premise_e1.result_value)] + env
      premise_e2 = e2(new_env)  # `e2` を新しい環境で評価
      eval_step = F13(env, expr_ast, premise_e2.result_value, premise_e1, premise_e2, x, premise_e1)  # F13: `let x = e1 in e2`
      return eval_step
    return _eval

  def fun(self,x,e):
    def _eval(env):
      expr_ast = AFun(x,e)
      result_value = Clos2(x,e,env)
      eval_step = F15(env,expr_ast,result_value,x)
      return eval_step
    return _eval

  def rec(self,f,x,e):
    def _eval(env):
      expr_ast = ARec(f,x,e)
      result_value = ClosRec2(f,x,e,env)
      eval_step = F16(env,expr_ast,result_value,f,x)
      return eval_step
    return _eval

  def app(self,e1,e2):
    # e1が関数 or 再帰かどうかで処理が変わる
    def _eval(env):
      premise_e1 = e1(env)
      expr_ast = AApp(e1,e2)
      # e1がクロージャじゃない
      if isinstance(premise_e1.result_value,Err2):
        eval_step = F20(env, expr_ast,premise_e1.result_value, premise_e1, premise_e2, premise_e1)
        return eval_step

      premise_e2 = e2(env)
      # e2の評価がエラー

      if isinstance(premise_e2.result_value,Err2):
        eval_step = F19(env,expr_ast,premise_e2.result_value,premise_e1,premise_e2,premise_e1)
        return eval_step
      if isinstance(premise_e1.result_value, Clos2):  # 通常の関数適用
          new_env = [(premise_e1.result_value.x, premise_e2.result_value)] + premise_e1.env
          premise_body = premise_e1.result_value.e(new_env)  # 関数本体を新しい環境で評価
          eval_step = F17(env, expr_ast, premise_body, premise_e1, premise_e2, premise_body, premise_e1, premise_e2)  # F17: `Clos2` の適用

      elif isinstance(premise_e1.result_value, ClosRec2):  # 再帰関数適用
          new_env = [(premise_e1.result_value.x, premise_e2.result_value), (premise_e1.result_value.f, premise_e1.result_value)] + premise_e1.env
          premise_body = premise_e1.e(new_env)  # 関数本体を新しい環境で評価
          eval_step = F18(env, expr_ast, premise_body, premise_e1, premise_e2, premise_body, premise_e1, premise_e2)  # F18: `ClosRec2` の適用
      else:
          eval_step = F20(env, expr_ast, E_Typ2(), premise_e1, premise_e2, premise_e1)  # F20: `e1` が関数でない場合の型エラー

      return eval_step
    return _eval

# %% [markdown]
# You can check your `Exp2EvalTreeGenerator` is correct or not by:
# ```python
# tree = let_example(Exp2EvalTreeGenerator())
# print(tree.pretty_print())
# ```
# The above code will generate LaTeX code to render the derivation tree.

# %%
tree = let_example(Exp2EvalTreeGenerator())([])
tree
# Out:
# F13_Let(expr='(let x = <function Exp2EvalTreeGenerator.cint.<locals>._eval at 0x7af08476a340> in <function Exp2EvalTreeGenerator.plus.<locals>._eval at 0x7af0845113a0>)', res='15', premises_count=2)

# %% [markdown]
# ## A5.

# %% [markdown]
# **Objective:**
#
# The goal of this assignment is to define and implement a Call-by-Name (CbN) evaluation function for the `Exp2` language. This evaluation function must be consistent with the Call-by-Name operational semantics discussed in the lecture slides (rules F'11-F'17). You will implement this evaluator as a Python class, say `CbNEval2Alg`, that is a subclass of `Exp2Alg`.
#
# **Background:**
#
# Call-by-Name evaluation differs significantly from Call-by-Value. Key principles include:
# * **Delayed Evaluation:** Arguments to functions and expressions bound in `let` are not evaluated until their value is actually needed.
# * **Thunks:** Instead of passing values, CbN passes "thunks" (or "frozen expressions"). A thunk encapsulates an unevaluated expression and the environment in which it was defined. You should define `Thunk` class to represent them as a subclass of `Value`.
# * **Environment:** The evaluation environment will bind variables not only to direct values (like integers or booleans if they've been forced) but also to these thunks.
#
# You should refer to the lecture slides:
# * Call-by-Name operational semantics (focusing on rules F'11, F'13, F'14, F'15, F'16).
# * The general strategy of algebra methods returning computations (functions from environment to result) is still applicable, but the nature of these computations and the values they handle will change for CbN.
#
# You will use parts of the provided `chap3lib.py`:
# * Value classes: `Val2` (as a base), `VInt2`, `VBool2`.
# * Error classes: `Err2`, `E_Typ2`, `E_Exec2`, `E_Undef2`.
